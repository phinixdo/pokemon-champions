# %%
# import modules

import requests
from bs4 import BeautifulSoup
import re
from time import sleep
import csv
import pandas as pd

# %%
# url of pokemon list
url = 'https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number'

# mine content
r = requests.get(url)

# gather text
html_content = r.text

# convert html into beautiful soup object
soup = BeautifulSoup(html_content, 'lxml')

# %%
# Title tag of soup object
soup.title.string
# Out:
# 'List of Pokémon by National Pokédex number - Bulbapedia, the community-driven Pokémon encyclopedia'

# %%
# Create pokemon list of Bulbapedia links

# gather all lines with links from beautiful soup object
http_links = soup.find_all('a', {'href': re.compile(r'\(Pok%C3%A9mon\)')})

# append link to pokemon list
pokemon_links = []
for link in http_links:
    if link['href'] not in pokemon_links:
        pokemon_links.append(link['href'])

# %%
# check for 809 Pokemon (includes Meltan & Melmetal)
len(pokemon_links)
# Out:
# 809

# %%
# url of pokemon 
url_poke = 'https://bulbapedia.bulbagarden.net' + pokemon_links[1]

# mine content
r_poke = requests.get(url_poke)

# gather text
html_content_poke = r_poke.text

soup_poke = BeautifulSoup(html_content_poke, 'lxml')

# %%
soup.find_all('a', {'id': re.compile(r'top')})
# Out:
# [<a id="top"></a>]

# %%
# filter for stats

# hp
soup_poke.find_all('th', {'style': re.compile(r'#FA92B2; width: 30px')})[0].string.strip()

# attack
soup_poke.find_all('th', {'style': re.compile(r'#F5AC78; width: 30px')})[0].string.strip()

# stats and corresponding color bands on bulbapedia stat table
stats = ['hp', 'attack', 'defense', 'sp.atk', 'sp.def', 'speed']
colorbands = ['#FA92B2','#F5AC78','#FAE078','#9DB7F5','#A7DB8D','#FA92B2']

# %%
soup_poke.find_all('big')[0].string.strip()#, {'style': re.compile(r'#FA92B2; width: 30px')})
# Out:
# 'Bulbasaur'

# %%
# function to pull a list of pokemon names with stats from bulbapedia

def poke_web_scrape(url_list):
    '''
    Scrape bulbapedia webite for pokemon name and stats
    
    input: list of wiki suffix
    output: list of lists with pokemon name and stats
    '''
    for poke_link in url_list:
        
        # obtain html
        url_poke = 'https://bulbapedia.bulbagarden.net' + poke_link
        r_poke = requests.get(url_poke)
        html_content_poke = r_poke.text
        soup_poke = r_poke = BeautifulSoup(html_content_poke, 'lxml')
        
        # initialize list
        poke_list = []
        
        # obtain pokemon name and append to list
        poke_name = soup_poke.find_all('big')[0].string.strip()
        poke_list.append(poke_name)
        
        # obtain hp, attack, defense, sp.atk, sp.def, and speed stats
        for colorband in colorbands:
            stat_string = colorbands[0]+'; width: 30px'
            stat_value = soup_poke.find_all('th', {'style': re.compile(stat_string)})[0].string.strip()
            poke_list.append(stat_value)
            
        poke_table.append(poke_list)    
    
    
    sleep(1)
    
    return poke_table

# %%
poke_table = []
table_values = poke_web_scrape(pokemon_links)
# Out:
# [['Victini', '100', '100', '100', '100', '100', '100'],
#  ['Bulbasaur', '45', '45', '45', '45', '45', '45'],
#  ['Ivysaur', '60', '60', '60', '60', '60', '60'],
#  ['Venusaur', '80', '80', '80', '80', '80', '80'],
#  ['Charmander', '65', '65', '65', '65', '65', '65'],
#  ['Charmeleon', '80', '80', '80', '80', '80', '80'],
#  ['Charizard', '100', '100', '100', '100', '100', '100'],
#  ['Squirtle', '43', '43', '43', '43', '43', '43'],
#  ['Wartortle', '58', '58', '58', '58', '58', '58'],
#  ['Blastoise', '78', '78', '78', '78', '78', '78'],
#  ['Caterpie', '45', '45', '45', '45', '45', '45'],
#  ['Metapod', '30', '30', '30', '30', '30', '30'],
#  ['Butterfree', '70', '70', '70', '70', '70', '70'],
#  ['Weedle', '50', '50', '50', '50', '50', '50'],
#  ['Kakuna', '35', '35', '35', '35', '35', '35'],
#  ['Beedrill', '75', '75', '75', '75', '75', '75'],
#  ['Pidgey', '56', '56', '56', '56', '56', '56'],
#  ['Pidgeotto', '71', '71', '71', '71', '71', '71'],
#  ['Pidgeot', '91', '91', '91', '91', '91', '91'],
#  ['Rattata', '72', '72', '72', '72', '72', '72'],
#  ['Raticate', '97', '97', '97', '97', '97', '97'],
#  ['Spearow', '70', '70', '70', '70', '70', '70'],
#  ['Fearow', '100', '100', '100', '100', '100', '100'],
#  ['Ekans', '55', '55', '55', '55', '55', '55'],
#  ['Arbok', '80', '80', '80', '80', '80', '80'],
#  ['Pikachu', '90', '90', '90', '90', '90', '90'],
#  ['Raichu', '100', '100', '100', '100', '100', '100'],
#  ['Sandshrew', '40', '40', '40', '40', '40', '40'],
#  ['Sandslash', '65', '65', '65', '65', '65', '65'],
#  ['Nidoran♀', '41', '41', '41', '41', '41', '41'],
#  ['Nidorina', '56', '56', '56', '56', '56', '56'],
#  ['Nidoqueen', '76', '76', '76', '76', '76', '76'],
#  ['Nidoran♂', '50', '50', '50', '50', '50', '50'],
#  ['Nidorino', '65', '65', '65', '65', '65', '65'],
#  ['Nidoking', '85', '85', '85', '85', '85', '85'],
#  ['Clefairy', '35', '35', '35', '35', '35', '35'],
#  ['Clefable', '60', '60', '60', '60', '60', '60'],
#  ['Vulpix', '65', '65', '65', '65', '65', '65'],
#  ['Ninetales', '100', '100', '100', '100', '100', '100'],
#  ['Jigglypuff', '20', '20', '20', '20', '20', '20'],
#  ['Wigglytuff', '45', '45', '45', '45', '45', '45'],
#  ['Zubat', '55', '55', '55', '55', '55', '55'],
#  ['Golbat', '90', '90', '90', '90', '90', '90'],
#  ['Oddish', '30', '30', '30', '30', '30', '30'],
#  ['Gloom', '40', '40', '40', '40', '40', '40'],
#  ['Vileplume', '50', '50', '50', '50', '50', '50'],
#  ['Paras', '25', '25', '25', '25', '25', '25'],
#  ['Parasect', '30', '30', '30', '30', '30', '30'],
#  ['Venonat', '45', '45', '45', '45', '45', '45'],
#  ['Venomoth', '90', '90', '90', '90', '90', '90'],
#  ['Diglett', '95', '95', '95', '95', '95', '95'],
#  ['Dugtrio', '120', '120', '120', '120', '120', '120'],
#  ['Meowth', '90', '90', '90', '90', '90', '90'],
#  ['Persian', '115', '115', '115', '115', '115', '115'],
#  ['Psyduck', '55', '55', '55', '55', '55', '55'],
#  ['Golduck', '85', '85', '85', '85', '85', '85'],
#  ['Mankey', '70', '70', '70', '70', '70', '70'],
#  ['Primeape', '95', '95', '95', '95', '95', '95'],
#  ['Growlithe', '60', '60', '60', '60', '60', '60'],
#  ['Arcanine', '95', '95', '95', '95', '95', '95'],
#  ['Poliwag', '90', '90', '90', '90', '90', '90'],
#  ['Poliwhirl', '90', '90', '90', '90', '90', '90'],
#  ['Poliwrath', '70', '70', '70', '70', '70', '70'],
#  ['Abra', '90', '90', '90', '90', '90', '90'],
#  ['Kadabra', '105', '105', '105', '105', '105', '105'],
#  ['Alakazam', '120', '120', '120', '120', '120', '120'],
#  ['Machop', '35', '35', '35', '35', '35', '35'],
#  ['Machoke', '45', '45', '45', '45', '45', '45'],
#  ['Machamp', '55', '55', '55', '55', '55', '55'],
#  ['Bellsprout', '40', '40', '40', '40', '40', '40'],
#  ['Weepinbell', '55', '55', '55', '55', '55', '55'],
#  ['Victreebel', '70', '70', '70', '70', '70', '70'],
#  ['Tentacool', '70', '70', '70', '70', '70', '70'],
#  ['Tentacruel', '100', '100', '100', '100', '100', '100'],
#  ['Geodude', '20', '20', '20', '20', '20', '20'],
#  ['Graveler', '35', '35', '35', '35', '35', '35'],
#  ['Golem', '45', '45', '45', '45', '45', '45'],
#  ['Ponyta', '90', '90', '90', '90', '90', '90'],
#  ['Rapidash', '105', '105', '105', '105', '105', '105'],
#  ['Slowpoke', '15', '15', '15', '15', '15', '15'],
#  ['Slowbro', '30', '30', '30', '30', '30', '30'],
#  ['Magnemite', '45', '45', '45', '45', '45', '45'],
#  ['Magneton', '70', '70', '70', '70', '70', '70'],
#  ["Farfetch'd", '60', '60', '60', '60', '60', '60'],
#  ['Doduo', '75', '75', '75', '75', '75', '75'],
#  ['Dodrio', '100', '100', '100', '100', '100', '100'],
#  ['Seel', '45', '45', '45', '45', '45', '45'],
#  ['Dewgong', '70', '70', '70', '70', '70', '70'],
#  ['Grimer', '25', '25', '25', '25', '25', '25'],
#  ['Muk', '50', '50', '50', '50', '50', '50'],
#  ['Shellder', '40', '40', '40', '40', '40', '40'],
#  ['Cloyster', '70', '70', '70', '70', '70', '70'],
#  ['Gastly', '80', '80', '80', '80', '80', '80'],
#  ['Haunter', '95', '95', '95', '95', '95', '95'],
#  ['Gengar', '110', '110', '110', '110', '110', '110'],
#  ['Onix', '70', '70', '70', '70', '70', '70'],
#  ['Drowzee', '42', '42', '42', '42', '42', '42'],
#  ['Hypno', '67', '67', '67', '67', '67', '67'],
#  ['Krabby', '50', '50', '50', '50', '50', '50'],
#  ['Kingler', '75', '75', '75', '75', '75', '75'],
#  ['Voltorb', '100', '100', '100', '100', '100', '100'],
#  ['Electrode', '140', '140', '140', '140', '140', '140'],
#  ['Exeggcute', '40', '40', '40', '40', '40', '40'],
#  ['Exeggutor', '55', '55', '55', '55', '55', '55'],
#  ['Cubone', '35', '35', '35', '35', '35', '35'],
#  ['Marowak', '45', '45', '45', '45', '45', '45'],
#  ['Hitmonlee', '87', '87', '87', '87', '87', '87'],
#  ['Hitmonchan', '76', '76', '76', '76', '76', '76'],
#  ['Lickitung', '30', '30', '30', '30', '30', '30'],
#  ['Koffing', '35', '35', '35', '35', '35', '35'],
#  ['Weezing', '60', '60', '60', '60', '60', '60'],
#  ['Rhyhorn', '25', '25', '25', '25', '25', '25'],
#  ['Rhydon', '40', '40', '40', '40', '40', '40'],
#  ['Chansey', '50', '50', '50', '50', '50', '50'],
#  ['Tangela', '60', '60', '60', '60', '60', '60'],
#  ['Kangaskhan', '90', '90', '90', '90', '90', '90'],
#  ['Horsea', '60', '60', '60', '60', '60', '60'],
#  ['Seadra', '85', '85', '85', '85', '85', '85'],
#  ['Goldeen', '63', '63', '63', '63', '63', '63'],
#  ['Seaking', '68', '68', '68', '68', '68', '68'],
#  ['Staryu', '85', '85', '85', '85', '85', '85'],
#  ['Starmie', '115', '115', '115', '115', '115', '115'],
#  ['Mr. Mime', '90', '90', '90', '90', '90', '90'],
#  ['Scyther', '105', '105', '105', '105', '105', '105'],
#  ['Jynx', '95', '95', '95', '95', '95', '95'],
#  ['Electabuzz', '105', '105', '105', '105', '105', '105'],
#  ['Magmar', '93', '93', '93', '93', '93', '93'],
#  ['Pinsir', '85', '85', '85', '85', '85', '85'],
#  ['Tauros', '110', '110', '110', '110', '110', '110'],
#  ['Magikarp', '80', '80', '80', '80', '80', '80'],
#  ['Gyarados', '81', '81', '81', '81', '81', '81'],
#  ['Lapras', '60', '60', '60', '60', '60', '60'],
#  ['Ditto', '48', '48', '48', '48', '48', '48'],
#  ['Eevee', '55', '55', '55', '55', '55', '55'],
#  ['Vaporeon', '65', '65', '65', '65', '65', '65'],
#  ['Jolteon', '130', '130', '130', '130', '130', '130'],
#  ['Flareon', '65', '65', '65', '65', '65', '65'],
#  ['Porygon', '40', '40', '40', '40', '40', '40'],
#  ['Omanyte', '35', '35', '35', '35', '35', '35'],
#  ['Omastar', '55', '55', '55', '55', '55', '55'],
#  ['Kabuto', '55', '55', '55', '55', '55', '55'],
#  ['Kabutops', '80', '80', '80', '80', '80', '80'],
#  ['Aerodactyl', '130', '130', '130', '130', '130', '130'],
#  ['Snorlax', '30', '30', '30', '30', '30', '30'],
#  ['Articuno', '85', '85', '85', '85', '85', '85'],
#  ['Zapdos', '100', '100', '100', '100', '100', '100'],
#  ['Moltres', '90', '90', '90', '90', '90', '90'],
#  ['Dratini', '50', '50', '50', '50', '50', '50'],
#  ['Dragonair', '70', '70', '70', '70', '70', '70'],
#  ['Dragonite', '80', '80', '80', '80', '80', '80'],
#  ['Mewtwo', '130', '130', '130', '130', '130', '130'],
#  ['Mew', '100', '100', '100', '100', '100', '100'],
#  ['Chikorita', '45', '45', '45', '45', '45', '45'],
#  ['Bayleef', '60', '60', '60', '60', '60', '60'],
#  ['Meganium', '80', '80', '80', '80', '80', '80'],
#  ['Cyndaquil', '65', '65', '65', '65', '65', '65'],
#  ['Quilava', '80', '80', '80', '80', '80', '80'],
#  ['Typhlosion', '100', '100', '100', '100', '100', '100'],
#  ['Totodile', '43', '43', '43', '43', '43', '43'],
#  ['Croconaw', '58', '58', '58', '58', '58', '58'],
#  ['Feraligatr', '78', '78', '78', '78', '78', '78'],
#  ['Sentret', '20', '20', '20', '20', '20', '20'],
#  ['Furret', '90', '90', '90', '90', '90', '90'],
#  ['Hoothoot', '50', '50', '50', '50', '50', '50'],
#  ['Noctowl', '70', '70', '70', '70', '70', '70'],
#  ['Ledyba', '55', '55', '55', '55', '55', '55'],
#  ['Ledian', '85', '85', '85', '85', '85', '85'],
#  ['Spinarak', '30', '30', '30', '30', '30', '30'],
#  ['Ariados', '40', '40', '40', '40', '40', '40'],
#  ['Crobat', '130', '130', '130', '130', '130', '130'],
#  ['Chinchou', '67', '67', '67', '67', '67', '67'],
#  ['Lanturn', '67', '67', '67', '67', '67', '67'],
#  ['Pichu', '60', '60', '60', '60', '60', '60'],
#  ['Cleffa', '15', '15', '15', '15', '15', '15'],
#  ['Igglybuff', '15', '15', '15', '15', '15', '15'],
#  ['Togepi', '20', '20', '20', '20', '20', '20'],
#  ['Togetic', '40', '40', '40', '40', '40', '40'],
#  ['Natu', '70', '70', '70', '70', '70', '70'],
#  ['Xatu', '95', '95', '95', '95', '95', '95'],
#  ['Mareep', '35', '35', '35', '35', '35', '35'],
#  ['Flaaffy', '45', '45', '45', '45', '45', '45'],
#  ['Ampharos', '55', '55', '55', '55', '55', '55'],
#  ['Bellossom', '50', '50', '50', '50', '50', '50'],
#  ['Marill', '40', '40', '40', '40', '40', '40'],
#  ['Azumarill', '50', '50', '50', '50', '50', '50'],
#  ['Sudowoodo', '30', '30', '30', '30', '30', '30'],
#  ['Politoed', '70', '70', '70', '70', '70', '70'],
#  ['Hoppip', '50', '50', '50', '50', '50', '50'],
#  ['Skiploom', '80', '80', '80', '80', '80', '80'],
#  ['Jumpluff', '110', '110', '110', '110', '110', '110'],
#  ['Aipom', '85', '85', '85', '85', '85', '85'],
#  ['Sunkern', '30', '30', '30', '30', '30', '30'],
#  ['Sunflora', '30', '30', '30', '30', '30', '30'],
#  ['Yanma', '95', '95', '95', '95', '95', '95'],
#  ['Wooper', '15', '15', '15', '15', '15', '15'],
#  ['Quagsire', '35', '35', '35', '35', '35', '35'],
#  ['Espeon', '110', '110', '110', '110', '110', '110'],
#  ['Umbreon', '65', '65', '65', '65', '65', '65'],
#  ['Murkrow', '91', '91', '91', '91', '91', '91'],
#  ['Slowking', '30', '30', '30', '30', '30', '30'],
#  ['Misdreavus', '85', '85', '85', '85', '85', '85'],
#  ['Unown', '48', '48', '48', '48', '48', '48'],
#  ['Wobbuffet', '33', '33', '33', '33', '33', '33'],
#  ['Girafarig', '85', '85', '85', '85', '85', '85'],
#  ['Pineco', '15', '15', '15', '15', '15', '15'],
#  ['Forretress', '40', '40', '40', '40', '40', '40'],
#  ['Dunsparce', '45', '45', '45', '45', '45', '45'],
#  ['Gligar', '85', '85', '85', '85', '85', '85'],
#  ['Steelix', '30', '30', '30', '30', '30', '30'],
#  ['Snubbull', '30', '30', '30', '30', '30', '30'],
#  ['Granbull', '45', '45', '45', '45', '45', '45'],
#  ['Qwilfish', '85', '85', '85', '85', '85', '85'],
#  ['Scizor', '65', '65', '65', '65', '65', '65'],
#  ['Shuckle', '5', '5', '5', '5', '5', '5'],
#  ['Heracross', '85', '85', '85', '85', '85', '85'],
#  ['Sneasel', '115', '115', '115', '115', '115', '115'],
#  ['Teddiursa', '40', '40', '40', '40', '40', '40'],
#  ['Ursaring', '55', '55', '55', '55', '55', '55'],
#  ['Slugma', '20', '20', '20', '20', '20', '20'],
#  ['Magcargo', '30', '30', '30', '30', '30', '30'],
#  ['Swinub', '50', '50', '50', '50', '50', '50'],
#  ['Piloswine', '50', '50', '50', '50', '50', '50'],
#  ['Corsola', '35', '35', '35', '35', '35', '35'],
#  ['Remoraid', '65', '65', '65', '65', '65', '65'],
#  ['Octillery', '45', '45', '45', '45', '45', '45'],
#  ['Delibird', '75', '75', '75', '75', '75', '75'],
#  ['Mantine', '70', '70', '70', '70', '70', '70'],
#  ['Skarmory', '70', '70', '70', '70', '70', '70'],
#  ['Houndour', '65', '65', '65', '65', '65', '65'],
#  ['Houndoom', '95', '95', '95', '95', '95', '95'],
#  ['Kingdra', '85', '85', '85', '85', '85', '85'],
#  ['Phanpy', '40', '40', '40', '40', '40', '40'],
#  ['Donphan', '50', '50', '50', '50', '50', '50'],
#  ['Porygon2', '60', '60', '60', '60', '60', '60'],
#  ['Stantler', '85', '85', '85', '85', '85', '85'],
#  ['Smeargle', '75', '75', '75', '75', '75', '75'],
#  ['Tyrogue', '35', '35', '35', '35', '35', '35'],
#  ['Hitmontop', '70', '70', '70', '70', '70', '70'],
#  ['Smoochum', '65', '65', '65', '65', '65', '65'],
#  ['Elekid', '95', '95', '95', '95', '95', '95'],
#  ['Magby', '83', '83', '83', '83', '83', '83'],
#  ['Miltank', '100', '100', '100', '100', '100', '100'],
#  ['Blissey', '55', '55', '55', '55', '55', '55'],
#  ['Raikou', '115', '115', '115', '115', '115', '115'],
#  ['Entei', '100', '100', '100', '100', '100', '100'],
#  ['Suicune', '85', '85', '85', '85', '85', '85'],
#  ['Larvitar', '41', '41', '41', '41', '41', '41'],
#  ['Pupitar', '51', '51', '51', '51', '51', '51'],
#  ['Tyranitar', '61', '61', '61', '61', '61', '61'],
#  ['Lugia', '110', '110', '110', '110', '110', '110'],
#  ['Ho-Oh', '90', '90', '90', '90', '90', '90'],
#  ['Celebi', '100', '100', '100', '100', '100', '100'],
#  ['Treecko', '70', '70', '70', '70', '70', '70'],
#  ['Grovyle', '95', '95', '95', '95', '95', '95'],
#  ['Sceptile', '120', '120', '120', '120', '120', '120'],
#  ['Torchic', '45', '45', '45', '45', '45', '45'],
#  ['Combusken', '55', '55', '55', '55', '55', '55'],
#  ['Blaziken', '80', '80', '80', '80', '80', '80'],
#  ['Mudkip', '40', '40', '40', '40', '40', '40'],
#  ['Marshtomp', '50', '50', '50', '50', '50', '50'],
#  ['Swampert', '60', '60', '60', '60', '60', '60'],
#  ['Poochyena', '35', '35', '35', '35', '35', '35'],
#  ['Mightyena', '70', '70', '70', '70', '70', '70'],
#  ['Zigzagoon', '60', '60', '60', '60', '60', '60'],
#  ['Linoone', '100', '100', '100', '100', '100', '100'],
#  ['Wurmple', '20', '20', '20', '20', '20', '20'],
#  ['Silcoon', '15', '15', '15', '15', '15', '15'],
#  ['Beautifly', '65', '65', '65', '65', '65', '65'],
#  ['Cascoon', '15', '15', '15', '15', '15', '15'],
#  ['Dustox', '65', '65', '65', '65', '65', '65'],
#  ['Lotad', '30', '30', '30', '30', '30', '30'],
#  ['Lombre', '50', '50', '50', '50', '50', '50'],
#  ['Ludicolo', '70', '70', '70', '70', '70', '70'],
#  ['Seedot', '30', '30', '30', '30', '30', '30'],
#  ['Nuzleaf', '60', '60', '60', '60', '60', '60'],
#  ['Shiftry', '80', '80', '80', '80', '80', '80'],
#  ['Taillow', '85', '85', '85', '85', '85', '85'],
#  ['Swellow', '125', '125', '125', '125', '125', '125'],
#  ['Wingull', '85', '85', '85', '85', '85', '85'],
#  ['Pelipper', '65', '65', '65', '65', '65', '65'],
#  ['Ralts', '40', '40', '40', '40', '40', '40'],
#  ['Kirlia', '50', '50', '50', '50', '50', '50'],
#  ['Gardevoir', '80', '80', '80', '80', '80', '80'],
#  ['Surskit', '65', '65', '65', '65', '65', '65'],
#  ['Masquerain', '60', '60', '60', '60', '60', '60'],
#  ['Shroomish', '35', '35', '35', '35', '35', '35'],
#  ['Breloom', '70', '70', '70', '70', '70', '70'],
#  ['Slakoth', '30', '30', '30', '30', '30', '30'],
#  ['Vigoroth', '90', '90', '90', '90', '90', '90'],
#  ['Slaking', '100', '100', '100', '100', '100', '100'],
#  ['Nincada', '40', '40', '40', '40', '40', '40'],
#  ['Ninjask', '160', '160', '160', '160', '160', '160'],
#  ['Shedinja', '40', '40', '40', '40', '40', '40'],
#  ['Whismur', '28', '28', '28', '28', '28', '28'],
#  ['Loudred', '48', '48', '48', '48', '48', '48'],
#  ['Exploud', '68', '68', '68', '68', '68', '68'],
#  ['Makuhita', '25', '25', '25', '25', '25', '25'],
#  ['Hariyama', '50', '50', '50', '50', '50', '50'],
#  ['Azurill', '20', '20', '20', '20', '20', '20'],
#  ['Nosepass', '30', '30', '30', '30', '30', '30'],
#  ['Skitty', '50', '50', '50', '50', '50', '50'],
#  ['Delcatty', '70', '70', '70', '70', '70', '70'],
#  ['Sableye', '50', '50', '50', '50', '50', '50'],
#  ['Mawile', '50', '50', '50', '50', '50', '50'],
#  ['Aron', '30', '30', '30', '30', '30', '30'],
#  ['Lairon', '40', '40', '40', '40', '40', '40'],
#  ['Aggron', '50', '50', '50', '50', '50', '50'],
#  ['Meditite', '60', '60', '60', '60', '60', '60'],
#  ['Medicham', '80', '80', '80', '80', '80', '80'],
#  ['Electrike', '65', '65', '65', '65', '65', '65'],
#  ['Manectric', '105', '105', '105', '105', '105', '105'],
#  ['Plusle', '95', '95', '95', '95', '95', '95'],
#  ['Minun', '95', '95', '95', '95', '95', '95'],
#  ['Volbeat', '85', '85', '85', '85', '85', '85'],
#  ['Illumise', '85', '85', '85', '85', '85', '85'],
#  ['Roselia', '65', '65', '65', '65', '65', '65'],
#  ['Gulpin', '40', '40', '40', '40', '40', '40'],
#  ['Swalot', '55', '55', '55', '55', '55', '55'],
#  ['Carvanha', '65', '65', '65', '65', '65', '65'],
#  ['Sharpedo', '95', '95', '95', '95', '95', '95'],
#  ['Wailmer', '60', '60', '60', '60', '60', '60'],
#  ['Wailord', '60', '60', '60', '60', '60', '60'],
#  ['Numel', '35', '35', '35', '35', '35', '35'],
#  ['Camerupt', '40', '40', '40', '40', '40', '40'],
#  ['Torkoal', '20', '20', '20', '20', '20', '20'],
#  ['Spoink', '60', '60', '60', '60', '60', '60'],
#  ['Grumpig', '80', '80', '80', '80', '80', '80'],
#  ['Spinda', '60', '60', '60', '60', '60', '60'],
#  ['Trapinch', '10', '10', '10', '10', '10', '10'],
#  ['Vibrava', '70', '70', '70', '70', '70', '70'],
#  ['Flygon', '100', '100', '100', '100', '100', '100'],
#  ['Cacnea', '35', '35', '35', '35', '35', '35'],
#  ['Cacturne', '55', '55', '55', '55', '55', '55'],
#  ['Swablu', '50', '50', '50', '50', '50', '50'],
#  ['Altaria', '80', '80', '80', '80', '80', '80'],
#  ['Zangoose', '90', '90', '90', '90', '90', '90'],
#  ['Seviper', '65', '65', '65', '65', '65', '65'],
#  ['Lunatone', '70', '70', '70', '70', '70', '70'],
#  ['Solrock', '70', '70', '70', '70', '70', '70'],
#  ['Barboach', '60', '60', '60', '60', '60', '60'],
#  ['Whiscash', '60', '60', '60', '60', '60', '60'],
#  ['Corphish', '35', '35', '35', '35', '35', '35'],
#  ['Crawdaunt', '55', '55', '55', '55', '55', '55'],
#  ['Baltoy', '55', '55', '55', '55', '55', '55'],
#  ['Claydol', '75', '75', '75', '75', '75', '75'],
#  ['Lileep', '23', '23', '23', '23', '23', '23'],
#  ['Cradily', '43', '43', '43', '43', '43', '43'],
#  ['Anorith', '75', '75', '75', '75', '75', '75'],
#  ['Armaldo', '45', '45', '45', '45', '45', '45'],
#  ['Feebas', '80', '80', '80', '80', '80', '80'],
#  ['Milotic', '81', '81', '81', '81', '81', '81'],
#  ['Castform', '70', '70', '70', '70', '70', '70'],
#  ['Kecleon', '40', '40', '40', '40', '40', '40'],
#  ['Shuppet', '45', '45', '45', '45', '45', '45'],
#  ['Banette', '65', '65', '65', '65', '65', '65'],
#  ['Duskull', '25', '25', '25', '25', '25', '25'],
#  ['Dusclops', '25', '25', '25', '25', '25', '25'],
#  ['Tropius', '51', '51', '51', '51', '51', '51'],
#  ['Chimecho', '65', '65', '65', '65', '65', '65'],
#  ['Absol', '75', '75', '75', '75', '75', '75'],
#  ['Wynaut', '23', '23', '23', '23', '23', '23'],
#  ['Snorunt', '50', '50', '50', '50', '50', '50'],
#  ['Glalie', '80', '80', '80', '80', '80', '80'],
#  ['Spheal', '25', '25', '25', '25', '25', '25'],
#  ['Sealeo', '45', '45', '45', '45', '45', '45'],
#  ['Walrein', '65', '65', '65', '65', '65', '65'],
#  ['Clamperl', '32', '32', '32', '32', '32', '32'],
#  ['Huntail', '52', '52', '52', '52', '52', '52'],
#  ['Gorebyss', '52', '52', '52', '52', '52', '52'],
#  ['Relicanth', '55', '55', '55', '55', '55', '55'],
#  ['Luvdisc', '97', '97', '97', '97', '97', '97'],
#  ['Bagon', '50', '50', '50', '50', '50', '50'],
#  ['Shelgon', '50', '50', '50', '50', '50', '50'],
#  ['Salamence', '100', '100', '100', '100', '100', '100'],
#  ['Beldum', '30', '30', '30', '30', '30', '30'],
#  ['Metang', '50', '50', '50', '50', '50', '50'],
#  ['Metagross', '70', '70', '70', '70', '70', '70'],
#  ['Regirock', '50', '50', '50', '50', '50', '50'],
#  ['Regice', '50', '50', '50', '50', '50', '50'],
#  ['Registeel', '50', '50', '50', '50', '50', '50'],
#  ['Latias', '110', '110', '110', '110', '110', '110'],
#  ['Latios', '110', '110', '110', '110', '110', '110'],
#  ['Kyogre', '90', '90', '90', '90', '90', '90'],
#  ['Groudon', '90', '90', '90', '90', '90', '90'],
#  ['Rayquaza', '95', '95', '95', '95', '95', '95'],
#  ['Jirachi', '100', '100', '100', '100', '100', '100'],
#  ['Deoxys', '150', '150', '150', '150', '150', '150'],
#  ['Turtwig', '31', '31', '31', '31', '31', '31'],
#  ['Grotle', '36', '36', '36', '36', '36', '36'],
#  ['Torterra', '56', '56', '56', '56', '56', '56'],
#  ['Chimchar', '61', '61', '61', '61', '61', '61'],
#  ['Monferno', '81', '81', '81', '81', '81', '81'],
#  ['Infernape', '108', '108', '108', '108', '108', '108'],
#  ['Piplup', '40', '40', '40', '40', '40', '40'],
#  ['Prinplup', '50', '50', '50', '50', '50', '50'],
#  ['Empoleon', '60', '60', '60', '60', '60', '60'],
#  ['Starly', '60', '60', '60', '60', '60', '60'],
#  ['Staravia', '80', '80', '80', '80', '80', '80'],
#  ['Staraptor', '100', '100', '100', '100', '100', '100'],
#  ['Bidoof', '31', '31', '31', '31', '31', '31'],
#  ['Bibarel', '71', '71', '71', '71', '71', '71'],
#  ['Kricketot', '25', '25', '25', '25', '25', '25'],
#  ['Kricketune', '65', '65', '65', '65', '65', '65'],
#  ['Shinx', '45', '45', '45', '45', '45', '45'],
#  ['Luxio', '60', '60', '60', '60', '60', '60'],
#  ['Luxray', '70', '70', '70', '70', '70', '70'],
#  ['Budew', '55', '55', '55', '55', '55', '55'],
#  ['Roserade', '90', '90', '90', '90', '90', '90'],
#  ['Cranidos', '58', '58', '58', '58', '58', '58'],
#  ['Rampardos', '58', '58', '58', '58', '58', '58'],
#  ['Shieldon', '30', '30', '30', '30', '30', '30'],
#  ['Bastiodon', '30', '30', '30', '30', '30', '30'],
#  ['Burmy', '36', '36', '36', '36', '36', '36'],
#  ['Wormadam', '36', '36', '36', '36', '36', '36'],
#  ['Mothim', '66', '66', '66', '66', '66', '66'],
#  ['Combee', '70', '70', '70', '70', '70', '70'],
#  ['Vespiquen', '40', '40', '40', '40', '40', '40'],
#  ['Pachirisu', '95', '95', '95', '95', '95', '95'],
#  ['Buizel', '85', '85', '85', '85', '85', '85'],
#  ['Floatzel', '115', '115', '115', '115', '115', '115'],
#  ['Cherubi', '35', '35', '35', '35', '35', '35'],
#  ['Cherrim', '85', '85', '85', '85', '85', '85'],
#  ['Shellos', '34', '34', '34', '34', '34', '34'],
#  ['Gastrodon', '39', '39', '39', '39', '39', '39'],
#  ['Ambipom', '115', '115', '115', '115', '115', '115'],
#  ['Drifloon', '70', '70', '70', '70', '70', '70'],
#  ['Drifblim', '80', '80', '80', '80', '80', '80'],
#  ['Buneary', '85', '85', '85', '85', '85', '85'],
#  ['Lopunny', '105', '105', '105', '105', '105', '105'],
#  ['Mismagius', '105', '105', '105', '105', '105', '105'],
#  ['Honchkrow', '71', '71', '71', '71', '71', '71'],
#  ['Glameow', '85', '85', '85', '85', '85', '85'],
#  ['Purugly', '112', '112', '112', '112', '112', '112'],
#  ['Chingling', '45', '45', '45', '45', '45', '45'],
#  ['Stunky', '74', '74', '74', '74', '74', '74'],
#  ['Skuntank', '84', '84', '84', '84', '84', '84'],
#  ['Bronzor', '23', '23', '23', '23', '23', '23'],
#  ['Bronzong', '33', '33', '33', '33', '33', '33'],
#  ['Bonsly', '10', '10', '10', '10', '10', '10'],
#  ['Mime Jr.', '60', '60', '60', '60', '60', '60'],
#  ['Happiny', '30', '30', '30', '30', '30', '30'],
#  ['Chatot', '91', '91', '91', '91', '91', '91'],
#  ['Spiritomb', '35', '35', '35', '35', '35', '35'],
#  ['Gible', '42', '42', '42', '42', '42', '42'],
#  ['Gabite', '82', '82', '82', '82', '82', '82'],
#  ['Garchomp', '102', '102', '102', '102', '102', '102'],
#  ['Munchlax', '5', '5', '5', '5', '5', '5'],
#  ['Riolu', '60', '60', '60', '60', '60', '60'],
#  ['Lucario', '90', '90', '90', '90', '90', '90'],
#  ['Hippopotas', '32', '32', '32', '32', '32', '32'],
#  ['Hippowdon', '47', '47', '47', '47', '47', '47'],
#  ['Skorupi', '65', '65', '65', '65', '65', '65'],
#  ['Drapion', '95', '95', '95', '95', '95', '95'],
#  ['Croagunk', '50', '50', '50', '50', '50', '50'],
#  ['Toxicroak', '85', '85', '85', '85', '85', '85'],
#  ['Carnivine', '46', '46', '46', '46', '46', '46'],
#  ['Finneon', '66', '66', '66', '66', '66', '66'],
#  ['Lumineon', '91', '91', '91', '91', '91', '91'],
#  ['Mantyke', '50', '50', '50', '50', '50', '50'],
#  ['Snover', '40', '40', '40', '40', '40', '40'],
#  ['Abomasnow', '60', '60', '60', '60', '60', '60'],
#  ['Weavile', '125', '125', '125', '125', '125', '125'],
#  ['Magnezone', '60', '60', '60', '60', '60', '60'],
#  ['Lickilicky', '50', '50', '50', '50', '50', '50'],
#  ['Rhyperior', '40', '40', '40', '40', '40', '40'],
#  ['Tangrowth', '50', '50', '50', '50', '50', '50'],
#  ['Electivire', '95', '95', '95', '95', '95', '95'],
#  ['Magmortar', '83', '83', '83', '83', '83', '83'],
#  ['Togekiss', '80', '80', '80', '80', '80', '80'],
#  ['Yanmega', '95', '95', '95', '95', '95', '95'],
#  ['Leafeon', '95', '95', '95', '95', '95', '95'],
#  ['Glaceon', '65', '65', '65', '65', '65', '65'],
#  ['Gliscor', '95', '95', '95', '95', '95', '95'],
#  ['Mamoswine', '80', '80', '80', '80', '80', '80'],
#  ['Porygon-Z', '90', '90', '90', '90', '90', '90'],
#  ['Gallade', '80', '80', '80', '80', '80', '80'],
#  ['Probopass', '40', '40', '40', '40', '40', '40'],
#  ['Dusknoir', '45', '45', '45', '45', '45', '45'],
#  ['Froslass', '110', '110', '110', '110', '110', '110'],
#  ['Rotom', '91', '91', '91', '91', '91', '91'],
#  ['Uxie', '95', '95', '95', '95', '95', '95'],
#  ['Mesprit', '80', '80', '80', '80', '80', '80'],
#  ['Azelf', '115', '115', '115', '115', '115', '115'],
#  ['Dialga', '90', '90', '90', '90', '90', '90'],
#  ['Palkia', '100', '100', '100', '100', '100', '100'],
#  ['Heatran', '77', '77', '77', '77', '77', '77'],
#  ['Regigigas', '100', '100', '100', '100', '100', '100'],
#  ['Giratina', '90', '90', '90', '90', '90', '90'],
#  ['Cresselia', '85', '85', '85', '85', '85', '85'],
#  ['Phione', '80', '80', '80', '80', '80', '80'],
#  ['Manaphy', '100', '100', '100', '100', '100', '100'],
#  ['Darkrai', '125', '125', '125', '125', '125', '125'],
#  ['Shaymin', '100', '100', '100', '100', '100', '100'],
#  ['Arceus', '120', '120', '120', '120', '120', '120'],
#  ['Snivy', '63', '63', '63', '63', '63', '63'],
#  ['Servine', '83', '83', '83', '83', '83', '83'],
#  ['Serperior', '113', '113', '113', '113', '113', '113'],
#  ['Tepig', '45', '45', '45', '45', '45', '45'],
#  ['Pignite', '55', '55', '55', '55', '55', '55'],
#  ['Emboar', '65', '65', '65', '65', '65', '65'],
#  ['Oshawott', '45', '45', '45', '45', '45', '45'],
#  ['Dewott', '60', '60', '60', '60', '60', '60'],
#  ['Samurott', '70', '70', '70', '70', '70', '70'],
#  ['Patrat', '42', '42', '42', '42', '42', '42'],
#  ['Watchog', '77', '77', '77', '77', '77', '77'],
#  ['Lillipup', '55', '55', '55', '55', '55', '55'],
#  ['Herdier', '60', '60', '60', '60', '60', '60'],
#  ['Stoutland', '80', '80', '80', '80', '80', '80'],
#  ['Purrloin', '66', '66', '66', '66', '66', '66'],
#  ['Liepard', '106', '106', '106', '106', '106', '106'],
#  ['Pansage', '64', '64', '64', '64', '64', '64'],
#  ['Simisage', '101', '101', '101', '101', '101', '101'],
#  ['Pansear', '64', '64', '64', '64', '64', '64'],
#  ['Simisear', '101', '101', '101', '101', '101', '101'],
#  ['Panpour', '64', '64', '64', '64', '64', '64'],
#  ['Simipour', '101', '101', '101', '101', '101', '101'],
#  ['Munna', '24', '24', '24', '24', '24', '24'],
#  ['Musharna', '29', '29', '29', '29', '29', '29'],
#  ['Pidove', '43', '43', '43', '43', '43', '43'],
#  ['Tranquill', '65', '65', '65', '65', '65', '65'],
#  ['Unfezant', '93', '93', '93', '93', '93', '93'],
#  ['Blitzle', '76', '76', '76', '76', '76', '76'],
#  ['Zebstrika', '116', '116', '116', '116', '116', '116'],
#  ['Roggenrola', '15', '15', '15', '15', '15', '15'],
#  ['Boldore', '20', '20', '20', '20', '20', '20'],
#  ['Gigalith', '25', '25', '25', '25', '25', '25'],
#  ['Woobat', '72', '72', '72', '72', '72', '72'],
#  ['Swoobat', '114', '114', '114', '114', '114', '114'],
#  ['Drilbur', '68', '68', '68', '68', '68', '68'],
#  ['Excadrill', '88', '88', '88', '88', '88', '88'],
#  ['Audino', '50', '50', '50', '50', '50', '50'],
#  ['Timburr', '35', '35', '35', '35', '35', '35'],
#  ['Gurdurr', '40', '40', '40', '40', '40', '40'],
#  ['Conkeldurr', '45', '45', '45', '45', '45', '45'],
#  ['Tympole', '64', '64', '64', '64', '64', '64'],
#  ['Palpitoad', '69', '69', '69', '69', '69', '69'],
#  ['Seismitoad', '74', '74', '74', '74', '74', '74'],
#  ['Throh', '45', '45', '45', '45', '45', '45'],
#  ['Sawk', '85', '85', '85', '85', '85', '85'],
#  ['Sewaddle', '42', '42', '42', '42', '42', '42'],
#  ['Swadloon', '42', '42', '42', '42', '42', '42'],
#  ['Leavanny', '92', '92', '92', '92', '92', '92'],
#  ['Venipede', '57', '57', '57', '57', '57', '57'],
#  ['Whirlipede', '47', '47', '47', '47', '47', '47'],
#  ['Scolipede', '112', '112', '112', '112', '112', '112'],
#  ['Cottonee', '66', '66', '66', '66', '66', '66'],
#  ['Whimsicott', '116', '116', '116', '116', '116', '116'],
#  ['Petilil', '30', '30', '30', '30', '30', '30'],
#  ['Lilligant', '90', '90', '90', '90', '90', '90'],
#  ['Basculin', '98', '98', '98', '98', '98', '98'],
#  ['Sandile', '65', '65', '65', '65', '65', '65'],
#  ['Krokorok', '74', '74', '74', '74', '74', '74'],
#  ['Krookodile', '92', '92', '92', '92', '92', '92'],
#  ['Darumaka', '50', '50', '50', '50', '50', '50'],
#  ['Darmanitan', '95', '95', '95', '95', '95', '95'],
#  ['Maractus', '60', '60', '60', '60', '60', '60'],
#  ['Dwebble', '55', '55', '55', '55', '55', '55'],
#  ['Crustle', '45', '45', '45', '45', '45', '45'],
#  ['Scraggy', '48', '48', '48', '48', '48', '48'],
#  ['Scrafty', '58', '58', '58', '58', '58', '58'],
#  ['Sigilyph', '97', '97', '97', '97', '97', '97'],
#  ['Yamask', '30', '30', '30', '30', '30', '30'],
#  ['Cofagrigus', '30', '30', '30', '30', '30', '30'],
#  ['Tirtouga', '22', '22', '22', '22', '22', '22'],
#  ['Carracosta', '32', '32', '32', '32', '32', '32'],
#  ['Archen', '70', '70', '70', '70', '70', '70'],
#  ['Archeops', '110', '110', '110', '110', '110', '110'],
#  ['Trubbish', '65', '65', '65', '65', '65', '65'],
#  ['Garbodor', '75', '75', '75', '75', '75', '75'],
#  ['Zorua', '65', '65', '65', '65', '65', '65'],
#  ['Zoroark', '105', '105', '105', '105', '105', '105'],
#  ['Minccino', '75', '75', '75', '75', '75', '75'],
#  ['Cinccino', '115', '115', '115', '115', '115', '115'],
#  ['Gothita', '45', '45', '45', '45', '45', '45'],
#  ['Gothorita', '55', '55', '55', '55', '55', '55'],
#  ['Gothitelle', '65', '65', '65', '65', '65', '65'],
#  ['Solosis', '20', '20', '20', '20', '20', '20'],
#  ['Duosion', '30', '30', '30', '30', '30', '30'],
#  ['Reuniclus', '30', '30', '30', '30', '30', '30'],
#  ['Ducklett', '55', '55', '55', '55', '55', '55'],
#  ['Swanna', '98', '98', '98', '98', '98', '98'],
#  ['Vanillite', '44', '44', '44', '44', '44', '44'],
#  ['Vanillish', '59', '59', '59', '59', '59', '59'],
#  ['Vanilluxe', '79', '79', '79', '79', '79', '79'],
#  ['Deerling', '75', '75', '75', '75', '75', '75'],
#  ['Sawsbuck', '95', '95', '95', '95', '95', '95'],
#  ['Emolga', '103', '103', '103', '103', '103', '103'],
#  ['Karrablast', '60', '60', '60', '60', '60', '60'],
#  ['Escavalier', '20', '20', '20', '20', '20', '20'],
#  ['Foongus', '15', '15', '15', '15', '15', '15'],
#  ['Amoonguss', '30', '30', '30', '30', '30', '30'],
#  ['Frillish', '40', '40', '40', '40', '40', '40'],
#  ['Jellicent', '60', '60', '60', '60', '60', '60'],
#  ['Alomomola', '65', '65', '65', '65', '65', '65'],
#  ['Joltik', '65', '65', '65', '65', '65', '65'],
#  ['Galvantula', '108', '108', '108', '108', '108', '108'],
#  ['Ferroseed', '10', '10', '10', '10', '10', '10'],
#  ['Ferrothorn', '20', '20', '20', '20', '20', '20'],
#  ['Klink', '30', '30', '30', '30', '30', '30'],
#  ['Klang', '50', '50', '50', '50', '50', '50'],
#  ['Klinklang', '90', '90', '90', '90', '90', '90'],
#  ['Tynamo', '60', '60', '60', '60', '60', '60'],
#  ['Eelektrik', '40', '40', '40', '40', '40', '40'],
#  ['Eelektross', '50', '50', '50', '50', '50', '50'],
#  ['Elgyem', '30', '30', '30', '30', '30', '30'],
#  ['Beheeyem', '40', '40', '40', '40', '40', '40'],
#  ['Litwick', '20', '20', '20', '20', '20', '20'],
#  ['Lampent', '55', '55', '55', '55', '55', '55'],
#  ['Chandelure', '80', '80', '80', '80', '80', '80'],
#  ['Axew', '57', '57', '57', '57', '57', '57'],
#  ['Fraxure', '67', '67', '67', '67', '67', '67'],
#  ['Haxorus', '97', '97', '97', '97', '97', '97'],
#  ['Cubchoo', '40', '40', '40', '40', '40', '40'],
#  ['Beartic', '50', '50', '50', '50', '50', '50'],
#  ['Cryogonal', '105', '105', '105', '105', '105', '105'],
#  ['Shelmet', '25', '25', '25', '25', '25', '25'],
#  ['Accelgor', '145', '145', '145', '145', '145', '145'],
#  ['Stunfisk', '32', '32', '32', '32', '32', '32'],
#  ['Mienfoo', '65', '65', '65', '65', '65', '65'],
#  ['Mienshao', '105', '105', '105', '105', '105', '105'],
#  ['Druddigon', '48', '48', '48', '48', '48', '48'],
#  ['Golett', '35', '35', '35', '35', '35', '35'],
#  ['Golurk', '55', '55', '55', '55', '55', '55'],
#  ['Pawniard', '60', '60', '60', '60', '60', '60'],
#  ['Bisharp', '70', '70', '70', '70', '70', '70'],
#  ['Bouffalant', '55', '55', '55', '55', '55', '55'],
#  ['Rufflet', '60', '60', '60', '60', '60', '60'],
#  ['Braviary', '80', '80', '80', '80', '80', '80'],
#  ['Vullaby', '60', '60', '60', '60', '60', '60'],
#  ['Mandibuzz', '80', '80', '80', '80', '80', '80'],
#  ['Heatmor', '65', '65', '65', '65', '65', '65'],
#  ['Durant', '109', '109', '109', '109', '109', '109'],
#  ['Deino', '38', '38', '38', '38', '38', '38'],
#  ['Zweilous', '58', '58', '58', '58', '58', '58'],
#  ['Hydreigon', '98', '98', '98', '98', '98', '98'],
#  ['Larvesta', '60', '60', '60', '60', '60', '60'],
#  ['Volcarona', '100', '100', '100', '100', '100', '100'],
#  ['Cobalion', '108', '108', '108', '108', '108', '108'],
#  ['Terrakion', '108', '108', '108', '108', '108', '108'],
#  ['Virizion', '108', '108', '108', '108', '108', '108'],
#  ['Tornadus', '111', '111', '111', '111', '111', '111'],
#  ['Thundurus', '111', '111', '111', '111', '111', '111'],
#  ['Reshiram', '90', '90', '90', '90', '90', '90'],
#  ['Zekrom', '90', '90', '90', '90', '90', '90'],
#  ['Landorus', '101', '101', '101', '101', '101', '101'],
#  ['Kyurem', '95', '95', '95', '95', '95', '95'],
#  ['Keldeo', '108', '108', '108', '108', '108', '108'],
#  ['Meloetta', '90', '90', '90', '90', '90', '90'],
#  ['Genesect', '99', '99', '99', '99', '99', '99'],
#  ['Chespin', '38', '38', '38', '38', '38', '38'],
#  ['Quilladin', '57', '57', '57', '57', '57', '57'],
#  ['Chesnaught', '64', '64', '64', '64', '64', '64'],
#  ['Fennekin', '60', '60', '60', '60', '60', '60'],
#  ['Braixen', '73', '73', '73', '73', '73', '73'],
#  ['Delphox', '104', '104', '104', '104', '104', '104'],
#  ['Froakie', '71', '71', '71', '71', '71', '71'],
#  ['Frogadier', '97', '97', '97', '97', '97', '97'],
#  ['Greninja', '122', '122', '122', '122', '122', '122'],
#  ['Bunnelby', '57', '57', '57', '57', '57', '57'],
#  ['Diggersby', '78', '78', '78', '78', '78', '78'],
#  ['Fletchling', '62', '62', '62', '62', '62', '62'],
#  ['Fletchinder', '84', '84', '84', '84', '84', '84'],
#  ['Talonflame', '126', '126', '126', '126', '126', '126'],
#  ['Scatterbug', '35', '35', '35', '35', '35', '35'],
#  ['Spewpa', '29', '29', '29', '29', '29', '29'],
#  ['Vivillon', '89', '89', '89', '89', '89', '89'],
#  ['Litleo', '72', '72', '72', '72', '72', '72'],
#  ['Pyroar', '106', '106', '106', '106', '106', '106'],
#  ['Flabébé', '42', '42', '42', '42', '42', '42'],
#  ['Floette', '52', '52', '52', '52', '52', '52'],
#  ['Florges', '75', '75', '75', '75', '75', '75'],
#  ['Skiddo', '52', '52', '52', '52', '52', '52'],
#  ['Gogoat', '68', '68', '68', '68', '68', '68'],
#  ['Pancham', '43', '43', '43', '43', '43', '43'],
#  ['Pangoro', '58', '58', '58', '58', '58', '58'],
#  ['Furfrou', '102', '102', '102', '102', '102', '102'],
#  ['Espurr', '68', '68', '68', '68', '68', '68'],
#  ['Meowstic', '104', '104', '104', '104', '104', '104'],
#  ['Honedge', '28', '28', '28', '28', '28', '28'],
#  ['Doublade', '35', '35', '35', '35', '35', '35'],
#  ['Aegislash', '60', '60', '60', '60', '60', '60'],
#  ['Spritzee', '23', '23', '23', '23', '23', '23'],
#  ['Aromatisse', '29', '29', '29', '29', '29', '29'],
#  ['Swirlix', '49', '49', '49', '49', '49', '49'],
#  ['Slurpuff', '72', '72', '72', '72', '72', '72'],
#  ['Inkay', '45', '45', '45', '45', '45', '45'],
#  ['Malamar', '73', '73', '73', '73', '73', '73'],
#  ['Binacle', '50', '50', '50', '50', '50', '50'],
#  ['Barbaracle', '68', '68', '68', '68', '68', '68'],
#  ['Skrelp', '30', '30', '30', '30', '30', '30'],
#  ['Dragalge', '44', '44', '44', '44', '44', '44'],
#  ['Clauncher', '44', '44', '44', '44', '44', '44'],
#  ['Clawitzer', '59', '59', '59', '59', '59', '59'],
#  ['Helioptile', '70', '70', '70', '70', '70', '70'],
#  ['Heliolisk', '109', '109', '109', '109', '109', '109'],
#  ['Tyrunt', '48', '48', '48', '48', '48', '48'],
#  ['Tyrantrum', '71', '71', '71', '71', '71', '71'],
#  ['Amaura', '46', '46', '46', '46', '46', '46'],
#  ['Aurorus', '58', '58', '58', '58', '58', '58'],
#  ['Sylveon', '60', '60', '60', '60', '60', '60'],
#  ['Hawlucha', '118', '118', '118', '118', '118', '118'],
#  ['Dedenne', '101', '101', '101', '101', '101', '101'],
#  ['Carbink', '50', '50', '50', '50', '50', '50'],
#  ['Goomy', '40', '40', '40', '40', '40', '40'],
#  ['Sliggoo', '60', '60', '60', '60', '60', '60'],
#  ['Goodra', '80', '80', '80', '80', '80', '80'],
#  ['Klefki', '75', '75', '75', '75', '75', '75'],
#  ['Phantump', '38', '38', '38', '38', '38', '38'],
#  ['Trevenant', '56', '56', '56', '56', '56', '56'],
#  ['Pumpkaboo', '56', '56', '56', '56', '56', '56'],
#  ['Gourgeist', '99', '99', '99', '99', '99', '99'],
#  ['Bergmite', '28', '28', '28', '28', '28', '28'],
#  ['Avalugg', '28', '28', '28', '28', '28', '28'],
#  ['Noibat', '55', '55', '55', '55', '55', '55'],
#  ['Noivern', '123', '123', '123', '123', '123', '123'],
#  ['Xerneas', '99', '99', '99', '99', '99', '99'],
#  ['Yveltal', '99', '99', '99', '99', '99', '99'],
#  ['Zygarde', '95', '95', '95', '95', '95', '95'],
#  ['Diancie', '50', '50', '50', '50', '50', '50'],
#  ['Hoopa', '70', '70', '70', '70', '70', '70'],
#  ['Volcanion', '70', '70', '70', '70', '70', '70'],
#  ['Rowlet', '42', '42', '42', '42', '42', '42'],
#  ['Dartrix', '52', '52', '52', '52', '52', '52'],
#  ['Decidueye', '70', '70', '70', '70', '70', '70'],
#  ['Litten', '70', '70', '70', '70', '70', '70'],
#  ['Torracat', '90', '90', '90', '90', '90', '90'],
#  ['Incineroar', '60', '60', '60', '60', '60', '60'],
#  ['Popplio', '40', '40', '40', '40', '40', '40'],
#  ['Brionne', '50', '50', '50', '50', '50', '50'],
#  ['Primarina', '60', '60', '60', '60', '60', '60'],
#  ['Pikipek', '65', '65', '65', '65', '65', '65'],
#  ['Trumbeak', '75', '75', '75', '75', '75', '75'],
#  ['Toucannon', '60', '60', '60', '60', '60', '60'],
#  ['Yungoos', '45', '45', '45', '45', '45', '45'],
#  ['Gumshoos', '45', '45', '45', '45', '45', '45'],
#  ['Grubbin', '46', '46', '46', '46', '46', '46'],
#  ['Charjabug', '36', '36', '36', '36', '36', '36'],
#  ['Vikavolt', '43', '43', '43', '43', '43', '43'],
#  ['Crabrawler', '63', '63', '63', '63', '63', '63'],
#  ['Crabominable', '43', '43', '43', '43', '43', '43'],
#  ['Oricorio', '93', '93', '93', '93', '93', '93'],
#  ['Cutiefly', '84', '84', '84', '84', '84', '84'],
#  ['Ribombee', '124', '124', '124', '124', '124', '124'],
#  ['Rockruff', '60', '60', '60', '60', '60', '60'],
#  ['Lycanroc', '112', '112', '112', '112', '112', '112'],
#  ['Wishiwashi', '40', '40', '40', '40', '40', '40'],
#  ['Mareanie', '45', '45', '45', '45', '45', '45'],
#  ['Toxapex', '35', '35', '35', '35', '35', '35'],
#  ['Mudbray', '45', '45', '45', '45', '45', '45'],
#  ['Mudsdale', '35', '35', '35', '35', '35', '35'],
#  ['Dewpider', '27', '27', '27', '27', '27', '27'],
#  ['Araquanid', '42', '42', '42', '42', '42', '42'],
#  ['Fomantis', '35', '35', '35', '35', '35', '35'],
#  ['Lurantis', '45', '45', '45', '45', '45', '45'],
#  ['Morelull', '15', '15', '15', '15', '15', '15'],
#  ['Shiinotic', '30', '30', '30', '30', '30', '30'],
#  ['Salandit', '77', '77', '77', '77', '77', '77'],
#  ['Salazzle', '117', '117', '117', '117', '117', '117'],
#  ['Stufful', '50', '50', '50', '50', '50', '50'],
#  ['Bewear', '60', '60', '60', '60', '60', '60'],
#  ['Bounsweet', '32', '32', '32', '32', '32', '32'],
#  ['Steenee', '62', '62', '62', '62', '62', '62'],
#  ['Tsareena', '72', '72', '72', '72', '72', '72'],
#  ['Comfey', '100', '100', '100', '100', '100', '100'],
#  ['Oranguru', '60', '60', '60', '60', '60', '60'],
#  ['Passimian', '80', '80', '80', '80', '80', '80'],
#  ['Wimpod', '80', '80', '80', '80', '80', '80'],
#  ['Golisopod', '40', '40', '40', '40', '40', '40'],
#  ['Sandygast', '15', '15', '15', '15', '15', '15'],
#  ['Palossand', '35', '35', '35', '35', '35', '35'],
#  ['Pyukumuku', '5', '5', '5', '5', '5', '5'],
#  ['Type: Null', '59', '59', '59', '59', '59', '59'],
#  ['Silvally', '95', '95', '95', '95', '95', '95'],
#  ['Minior', '60', '60', '60', '60', '60', '60'],
#  ['Komala', '65', '65', '65', '65', '65', '65'],
#  ['Turtonator', '36', '36', '36', '36', '36', '36'],
#  ['Togedemaru', '96', '96', '96', '96', '96', '96'],
#  ['Mimikyu', '96', '96', '96', '96', '96', '96'],
#  ['Bruxish', '92', '92', '92', '92', '92', '92'],
#  ['Drampa', '36', '36', '36', '36', '36', '36'],
#  ['Dhelmise', '40', '40', '40', '40', '40', '40'],
#  ['Jangmo-o', '45', '45', '45', '45', '45', '45'],
#  ['Hakamo-o', '65', '65', '65', '65', '65', '65'],
#  ['Kommo-o', '85', '85', '85', '85', '85', '85'],
#  ['Tapu Koko', '130', '130', '130', '130', '130', '130'],
#  ['Tapu Lele', '95', '95', '95', '95', '95', '95'],
#  ['Tapu Bulu', '75', '75', '75', '75', '75', '75'],
#  ['Tapu Fini', '85', '85', '85', '85', '85', '85'],
#  ['Cosmog', '37', '37', '37', '37', '37', '37'],
#  ['Cosmoem', '37', '37', '37', '37', '37', '37'],
#  ['Solgaleo', '97', '97', '97', '97', '97', '97'],
#  ['Lunala', '97', '97', '97', '97', '97', '97'],
#  ['Nihilego', '103', '103', '103', '103', '103', '103'],
#  ['Buzzwole', '79', '79', '79', '79', '79', '79'],
#  ['Pheromosa', '151', '151', '151', '151', '151', '151'],
#  ['Xurkitree', '83', '83', '83', '83', '83', '83'],
#  ['Celesteela', '61', '61', '61', '61', '61', '61'],
#  ['Kartana', '109', '109', '109', '109', '109', '109'],
#  ['Guzzlord', '43', '43', '43', '43', '43', '43'],
#  ['Necrozma', '79', '79', '79', '79', '79', '79'],
#  ['Magearna', '65', '65', '65', '65', '65', '65'],
#  ['Marshadow', '125', '125', '125', '125', '125', '125'],
#  ['Poipole', '73', '73', '73', '73', '73', '73'],
#  ['Naganadel', '121', '121', '121', '121', '121', '121'],
#  ['Stakataka', '13', '13', '13', '13', '13', '13'],
#  ['Blacephalon', '107', '107', '107', '107', '107', '107'],
#  ['Zeraora', '143', '143', '143', '143', '143', '143'],
#  ['Meltan', '34', '34', '34', '34', '34', '34'],
#  ['Melmetal', '34', '34', '34', '34', '34', '34']]

# %%
headers = ['Name'] + stats

pokemon = pd.DataFrame(table_values, columns=headers)

# %%
pokemon.to_csv('data\pokemon', index=False)
